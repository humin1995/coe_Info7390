# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sns

# %%
data = pd.read_csv('PUBG_Player.csv', encoding='ISO-8859-1')
data.head()
# Out:
#      player_name  tracker_id  solo_KillDeathRatio  solo_WinRatio  \
# 0      BreakNeck        4405                 3.14          17.65
# 1      Blackwalk        8199                 4.41          18.18
# 2  mercedes_benz        4454                 3.60           0.00
# 3           DORA        7729                14.00          50.00
# 4        n2tstar           0                10.50          33.33
#
#    solo_RoundsPlayed  solo_Wins  solo_Rating  solo_DamagePg  solo_HealsPg  \
# 0                 17          3      1559.78         255.36          1.94
# 1                 33          6      1884.53         393.04          1.82
# 2                  5          0      1255.92         329.76          1.00
# 3                  8          4      1798.70         751.95          1.00
# 4                  6          2      1668.67         637.48          2.00
#
#    solo_KillsPg          ...            squad_DamagePg  squad_HealsPg  \
# 0          2.59          ...                    377.15           3.40
# 1          3.61          ...                    373.68           2.83
# 2          3.60          ...                    399.70           2.41
# 3          7.00          ...                    368.85           2.47
# 4          7.00          ...                    384.69           2.99
#
#    squad_KillsPg  squad_MoveDistancePg  squad_RevivesPg  squad_RoundMostKills  \
# 0           2.86               8091.57             0.36                    11
# 1           3.05               8381.97             0.38                    14
# 2           3.20               7625.66             0.29                    17
# 3           2.76               7733.03             0.29                    12
# 4           3.05               7741.01             0.29                    15
#
#    squad_AvgSurvivalTime  squad_WinPoints  squad_AvgWalkDistance  \
# 0                1449.03             4868                2626.97
# 1                1570.51             4058                2422.48
# 2                1223.28             5929                1871.89
# 3                1583.73             2576                2154.62
# 4                1608.96             2579                2098.47
#
#    squad_AvgRideDistance
# 0                4372.64
# 1                6009.73
# 2                3011.87
# 3                5578.41
# 4                5642.54
#
# [5 rows x 49 columns]

# %%
data.isnull().sum()
# Out:
# player_name              0
# tracker_id               0
# solo_KillDeathRatio      0
# solo_WinRatio            0
# solo_RoundsPlayed        0
# solo_Wins                0
# solo_Rating              0
# solo_DamagePg            0
# solo_HealsPg             0
# solo_KillsPg             0
# solo_MoveDistancePg      0
# solo_TimeSurvivedPg      0
# solo_RoundMostKills      0
# solo_AvgSurvivalTime     0
# solo_WinPoints           0
# solo_AvgWalkDistance     0
# solo_AvgRideDistance     0
# duo_KillDeathRatio       0
# duo_WinRatio             0
# duo_TimeSurvived         0
# duo_RoundsPlayed         0
# duo_Wins                 0
# duo_Rating               0
# duo_DamagePg             0
# duo_HealsPg              0
# duo_KillsPg              0
# duo_MoveDistancePg       0
# duo_RevivesPg            0
# duo_TimeSurvivedPg       0
# duo_RoundMostKills       0
# duo_AvgSurvivalTime      0
# duo_WinPoints            0
# duo_AvgWalkDistance      0
# duo_AvgRideDistance      0
# squad_KillDeathRatio     0
# squad_WinRatio           0
# squad_RoundsPlayed       0
# squad_Wins               0
# squad_Rating             0
# squad_DamagePg           0
# squad_HealsPg            0
# squad_KillsPg            0
# squad_MoveDistancePg     0
# squad_RevivesPg          0
# squad_RoundMostKills     0
# squad_AvgSurvivalTime    0
# squad_WinPoints          0
# squad_AvgWalkDistance    0
# squad_AvgRideDistance    0
# dtype: int64

# %%
data.describe()
# Out:
#           tracker_id  solo_KillDeathRatio  solo_WinRatio  solo_RoundsPlayed  \
# count   87898.000000         87898.000000   87898.000000       87898.000000
# mean   110794.357050             1.865855       5.017506          79.275342
# std     63648.581759             1.776301      10.077138          96.947859
# min         0.000000             0.000000       0.000000           1.000000
# 25%     51925.250000             1.030000       0.000000          17.000000
# 50%    112705.500000             1.470000       2.000000          48.000000
# 75%    164879.750000             2.140000       5.560000         105.000000
# max    222490.000000           100.000000     100.000000        1681.000000
#
#           solo_Wins   solo_Rating  solo_DamagePg  solo_HealsPg  solo_KillsPg  \
# count  87898.000000  87898.000000   87898.000000  87898.000000  87898.000000
# mean       2.080093   1768.627033     194.256103      1.415902      1.682336
# std        3.394513    348.721933     112.640548      0.894112      1.119798
# min        0.000000    984.580000       0.000000      0.000000      0.000000
# 25%        0.000000   1477.232500     126.550000      0.930000      1.010000
# 50%        1.000000   1754.210000     169.910000      1.290000      1.430000
# 75%        3.000000   2041.137500     231.520000      1.730000      2.000000
# max      106.000000   2967.090000    2029.420000     24.000000     20.000000
#
#        solo_MoveDistancePg          ...            squad_DamagePg  \
# count         87898.000000          ...              87898.000000
# mean           2829.960220          ...                178.878591
# std            1187.216867          ...                 88.036668
# min               0.000000          ...                  0.000000
# 25%            2049.835000          ...                123.952500
# 50%            2624.765000          ...                164.950000
# 75%            3385.937500          ...                216.670000
# max           26737.340000          ...               3136.460000
#
#        squad_HealsPg  squad_KillsPg  squad_MoveDistancePg  squad_RevivesPg  \
# count   87898.000000   87898.000000          87898.000000     87898.000000
# mean        1.918367       1.278843           3328.193673         0.219191
# std         0.720093       0.716828            820.901719         0.091496
# min         0.000000       0.000000              0.000000         0.000000
# 25%         1.460000       0.850000           2790.162500         0.160000
# 50%         1.830000       1.160000           3214.235000         0.210000
# 75%         2.280000       1.560000           3731.452500         0.260000
# max        28.000000      30.000000          10933.460000         4.000000
#
#        squad_RoundMostKills  squad_AvgSurvivalTime  squad_WinPoints  \
# count          87898.000000           87898.000000     87898.000000
# mean               8.219675            1041.520426      3010.636533
# std                3.360172             188.952385      1504.108122
# min                0.000000             102.290000       910.000000
# 25%                6.000000             921.592500      1710.000000
# 50%                8.000000            1031.305000      2742.000000
# 75%               10.000000            1155.477500      3948.000000
# max               81.000000            2029.280000     11060.000000
#
#        squad_AvgWalkDistance  squad_AvgRideDistance
# count           87898.000000           87898.000000
# mean             1630.826705            1772.866887
# std               433.957257             803.932786
# min                 0.000000               0.000000
# 25%              1377.460000            1226.412500
# 50%              1592.410000            1645.455000
# 75%              1847.200000            2177.837500
# max             47314.750000            9632.720000
#
# [8 rows x 48 columns]

# %%
from scipy import stats
import seaborn as sns
import statsmodels.api as sm
from sklearn import linear_model
from statsmodels.formula.api import ols
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
import warnings
warnings.filterwarnings('ignore')
# Out:
# D:\Anaconda\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
#anaylze solo 
data_solo=data[['solo_KillDeathRatio','solo_WinRatio','solo_Rating','solo_DamagePg','solo_HealsPg','solo_KillsPg','solo_MoveDistancePg','solo_TimeSurvivedPg'
]]
data_solo.head()
# Out:
#    solo_KillDeathRatio  solo_WinRatio  solo_Rating  solo_DamagePg  \
# 0                 3.14          17.65      1559.78         255.36
# 1                 4.41          18.18      1884.53         393.04
# 2                 3.60           0.00      1255.92         329.76
# 3                14.00          50.00      1798.70         751.95
# 4                10.50          33.33      1668.67         637.48
#
#    solo_HealsPg  solo_KillsPg  solo_MoveDistancePg  solo_TimeSurvivedPg
# 0          1.94          2.59              3321.28              1086.42
# 1          1.82          3.61              5021.41              1000.45
# 2          1.00          3.60              2804.80               866.09
# 3          1.00          7.00              5986.82              1677.73
# 4          2.00          7.00              6526.96              1640.17

# %%
solo_model = ols("solo_KillDeathRatio ~ solo_DamagePg + solo_HealsPg + solo_KillsPg + solo_MoveDistancePg + solo_TimeSurvivedPg -1", data=data_solo).fit()
solo_model.summary()
